# %% [markdown]
# # Section 1
#
# - We do *Data analysis* for what?
# - What are your questions to answered?
# - Why Pandas?
#
# - What do you think?
#
# What is this? Any idea or information about this image.
# ![caption](./images/blackhole.jpg)

# %% [markdown]
# ## Data science ecosystem and tech stack
#
# ![Data Science Tech Stack)](./images/Data-Science-Tech-Stack.png)

# %% [markdown]
# ## Review tech stack
# Let's review numpy page for ecosystem https://numpy.org/

# %% [markdown]
# ![caption](./images/Tech-Stack.png)

# %%
Review tech stack
review numpy page for ecosystem https://numpy.org/

numpy and other Python DS tech stack
https://numpy.org/case-studies/blackhole-image/

![](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)

![caption](./images/bh_numpy_role.png)


![caption](./images/Data Science Workflow.png)
![caption](./images/ds-landscape.png)
![caption](./images/numpy_bh_benefits.png)
![caption](./images/pydata_stack.png)
![caption](./images/Python-with-Data-Science.png)
![caption](./images/refah-stats-webpage.png)

# %% [markdown]
# # Section 2
# We will work on sample data provided at [sample stats from Refah database of Iranian welfare ](https://refahdb.mcls.gov.ir/fa/sample) by means of Pandas.
#
#
# پایگاه اطلاعات رفاه ایرانیان وزارت تعاون، کار و رفاه اجتماعی / نمونه 2 درصدی از پایگاه اطلاعات رفاه ایرانیان
#
#
# https://refahdb.mcls.gov.ir/fa/sample
#
# ![regah image](./images/refah-stats-webpage.png)

# %%
display(HTML('https://refahdb.mcls.gov.ir/fa/sample'))
# Out:
# <!DOCTYPE html>
# <html lang='fa' xml:lang='fa' itemscope itemtype="http://schema.org/WebPage">
# <head><meta charset="utf-8" /><meta http-equiv="X-UA-Compatible" content="IE=edge" /><meta name="viewport" content="width=device-width, initial-scale=1" /><title>
# 	نمونه 2 درصدی از پایگاه اطلاعات رفاه ایرانیان
# </title>
# <meta name="robots" content="index, follow" />
# <link href="/App_Themes/favicon.ico" rel="shortcut icon" type="image/x-icon" /><meta name="apple-mobile-web-app-title" content="پایگاه اطلاعات رفاه ایرانیان وزارت تعاون، کار و رفاه اجتماعی" /><link href="/App_Themes/touch-icon-iphone.png" rel="apple-touch-icon" /><link href="/App_Themes/touch-icon-ipad.png" rel="apple-touch-icon" sizes="76x76" /><link href="/App_Themes/touch-icon-iphone-retina.png" rel="apple-touch-icon" sizes="120x120" /><link href="/App_Themes/touch-icon-ipad-retina.png" rel="apple-touch-icon" sizes="152x152" />
# <meta name="DC.Identifier" content="https://refahdb.mcls.gov.ir/fa/sample" />
# ...

# %% [markdown]
# We use this dataset as sample to explore with Pandas. We delve into data by means of Pandas to get some information about data.
#
# Then we try to think of some questions about dataset to further investigate and answer them.
# ### Data analysis work flow
# ![Data_Analysis_ Workflow](./images/Data_Analysis_Workflow.jpg)
# ![regah image](./images/Data_Analysis_roadmap.png)

# %%
getcwd()
# Out:
# 'D:\\Digikala\\Python related projects\\Data on Refah Iranian\\480397_orig'

# %% [markdown]
# https://docs.aws.amazon.com/wellarchitected/latest/machine-learning-lens/well-architected-machine-learning-lifecycle.html
#
# ![caption](./images/well-architected-ml-lifecycle.png)

# %%
chdir(r'D:\Hesam\Data Science\Pandas course notebook')

# %%
for i in os.listdir('./images'):
    print('![caption](./images/'+ i +')',)
# Out:
# ![caption](./images/.ipynb_checkpoints)
# ![caption](./images/automation.png)
# ![caption](./images/bh_numpy_role.png)
# ![caption](./images/blackhole.jpg)
# ![caption](./images/Data-Science-Tech-Stack.png)
# ![caption](./images/Data-Science-Workflow.png)
# ![caption](./images/Data_Analysis_roadmap.png)
# ![caption](./images/Data_Analysis_Workflow.jpg)
# ![caption](./images/ds-landscape.png)
# ![caption](./images/numpy_bh_benefits.png)
# ![caption](./images/pydata_stack.png)
# ![caption](./images/Python-with-Data-Science.png)
# ![caption](./images/refah-stats-webpage.png)
# ![caption](./images/Tech-Stack.png)
# ![caption](./images/well-architected-ml-lifecycle.png)

# %%
import os
os.getcwd()
# Out:
# 'D:\\Hesam\\Data Science\\Pandas course notebook'

# %%
os.listdir('./images/')
# Out:
# ['bh_numpy_role.png',
#  'blackhole.jpg',
#  'Data Science Tech Stack.png',
#  'Data Science Workflow.png',
#  'ds-landscape.png',
#  'numpy_bh_benefits.png',
#  'pydata_stack.png',
#  'Python-with-Data-Science.png',
#  'refah stats webpage.png',
#  'Tech Stack.png']

# %%
!
# Out:
# '?' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !jupyter nbconvert --to script 'Course work - Part 2.ipynb'
# Out:
# This application is used to convert notebook files (*.ipynb) to various other
# [NbConvertApp] WARNING | pattern "'Course" matched no files
# [NbConvertApp] WARNING | pattern 'work' matched no files
# [NbConvertApp] WARNING | pattern '-' matched no files
# [NbConvertApp] WARNING | pattern 'Part' matched no files
# [NbConvertApp] WARNING | pattern "2.ipynb'" matched no files
# formats.
#
# WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# -y
#     Answer yes to any questions instead of prompting.
# ...

# %%
# %%writefile?
# Out:
# Docstring:
# ::
#
#   %writefile [-a] filename
#
# Write the contents of the cell to a file.
#
# The file will be overwritten unless the -a (--append) flag is specified.
#
# positional arguments:
#   filename      file to write
#
# optional arguments:
#   -a, --append  Append contents of the cell to an existing file. The file will
#                 be created if it does not exist.
# File:      d:\h.mohammadhosseini\anaconda3\lib\site-packages\ipython\core\magics\osm.py

# %%
#%%writefile section1_test.py
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

from os import chdir, listdir, getcwd

# %%
getcwd()
# Out:
# 'D:\\Digikala\\Python related projects\\Data on Refah Iranian\\480397_orig'

# %%
listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Course work - Part 2.ipynb',
#  'images',
#  'section1_test.py',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
chdir(r'D:\Digikala\Python related projects\Data on Refah Iranian\480397_orig')
# '\n' '\t' '\\'

# %%
listdir()
# Out:
# ['sample data.xlsx',
#  'Sample2Percent_FieldDesc_4000412.xlsx',
#  'Sample2Percent_Refah_4000412.xlsx.csv',
#  '~$Sample2Percent_FieldDesc_4000412.xlsx']

# %%
# https://refahdb.mcls.gov.ir/fa/sample

# 1. read data excel, csv , txt

# pd.read_csv()  # csv and txt
# pd.read_excel()  # excel
df = pd.read_csv('Sample2Percent_Refah_4000412.xlsx.csv', nrows = 1000)
# df.to_excel('sample data.xlsx')

# %%
df.head()
# Out:
#            ID    ParentID   BirthDate  GenderId  postalcode Provincename  \
# 0   385996899   391863876  1978-03-22         2   6451967.0      �������
# 1  2633686968  2633686968  1995-02-05         1   9577153.0  ������ ����
# 2   312125928  1981002597  1970-05-13         2   3898155.0         �ј��
# 3    70847160    70847160  1969-03-21         1   8318747.0       ������
# 4   663191175  9230116821  2004-06-19         2    451879.0        �����
#
#          countyname isurban  AmCrdtr_95  Amdbtr_95  ...  Cars_Count  \
# 0             �����    True   207500000  307500000  ...           0
# 1          ���� ���    True   137500000  110000000  ...           1
# 2              ����   False           0          0  ...           0
# 3  ����� ��� � ����    True   135000000  167500000  ...           1
# 4             �����    True     2500000          0  ...           0
#
#    CarsPrice_Sum  Trips_Count_AirNotPilgrimage  \
# 0              0                             0
# ...

# %%
df.dtypes
# Out:
# ID                                   int64
# ParentID                             int64
# BirthDate                           object
# GenderId                             int64
# postalcode                         float64
# Provincename                        object
# countyname                          object
# isurban                             object
# AmCrdtr_95                           int64
# Amdbtr_95                            int64
# frstPrd_95                           int64
# lstPrd_95                            int64
# SmBnft_95                            int64
# AmCrdtr_96                           int64
# Amdbtr_96                            int64
# frstPrd_96                           int64
# lstPrd_96                            int64
# SmBnft_96                            int64
# AmCrdtr_97                           int64
# Amdbtr_97                            int64
# frstPrd_97                           int64
# lstPrd_97                            int64
# ...

# %%
df.describe()
# Out:
#                  ID      ParentID     GenderId    postalcode    AmCrdtr_95  \
# count  1.000000e+03  1.000000e+03  1000.000000  9.830000e+02  1.000000e+03
# mean   5.630212e+09  5.173133e+09     1.471000  4.463070e+06  4.796175e+08
# std    3.414268e+09  3.074997e+09     0.499408  3.257402e+06  1.287718e+09
# min    1.922511e+06  2.862532e+07     1.000000  1.143640e+05  0.000000e+00
# 25%    2.721921e+09  2.543604e+09     1.000000  8.278035e+05  0.000000e+00
# 50%    5.647889e+09  4.978144e+09     1.000000  4.749183e+06  2.250000e+07
# 75%    8.441033e+09  7.809090e+09     2.000000  7.342624e+06  3.006250e+08
# max    1.335158e+10  1.237783e+10     2.000000  9.991635e+06  1.000000e+10
#
#           Amdbtr_95    frstPrd_95     lstPrd_95     SmBnft_95    AmCrdtr_96  \
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean   4.816325e+08  6.460750e+07  8.089000e+07  1.398000e+07  6.184575e+08
# ...

# %%
df.isna().sum()#.plot()#(kind='bar')
# Out:
# ID                                   0
# ParentID                             0
# BirthDate                            9
# GenderId                             0
# postalcode                          17
# Provincename                        17
# countyname                          17
# isurban                             17
# AmCrdtr_95                           0
# Amdbtr_95                            0
# frstPrd_95                           0
# lstPrd_95                            0
# SmBnft_95                            0
# AmCrdtr_96                           0
# Amdbtr_96                            0
# frstPrd_96                           0
# lstPrd_96                            0
# SmBnft_96                            0
# AmCrdtr_97                           0
# Amdbtr_97                            0
# frstPrd_97                           0
# lstPrd_97                            0
# SmBnft_97                            0
# AmCrdtr_98                           0
# ...

# %%
df.columns
# Out:
# Index(['ID', 'ParentID', 'BirthDate', 'GenderId', 'postalcode', 'Provincename',
#        'countyname', 'isurban', 'AmCrdtr_95', 'Amdbtr_95', 'frstPrd_95',
#        'lstPrd_95', 'SmBnft_95', 'AmCrdtr_96', 'Amdbtr_96', 'frstPrd_96',
#        'lstPrd_96', 'SmBnft_96', 'AmCrdtr_97', 'Amdbtr_97', 'frstPrd_97',
#        'lstPrd_97', 'SmBnft_97', 'AmCrdtr_98', 'Amdbtr_98', 'frstPrd_98',
#        'lstPrd_98', 'SmBnft_98', 'Card98_Rials', 'Card98_PaymentCount',
#        'Card99_Rials', 'Card99PaymentCount', 'IsBiamrKhas', 'IsMalool',
#        'IsBimePardaz_Sandoghha', 'IsBazneshaste_Sandoghha',
#        'IsMaliati_Shaghel', 'daramad_Total_Rials', 'Cars_Count',
#        'CarsPrice_Sum', 'Trips_Count_AirNotPilgrimage',
#        'Trips_Count_NotAirNotPilgrimage', 'Trips_Count_AirPilgrimage',
#        'Trips_Count_NotAirPilgrimage', 'HasMojavezSenfi', 'Senf',
#        'HasBimeSalamat', 'BimeSalmat_Type'],
#       dtype='object')

# %%
df_columns = pd.read_excel('Sample2Percent_FieldDesc_4000412.xlsx')

# %%
df_columns
# Out:
#                                    FieldName  \
# 0                                       [ID]
# 1                                ,[ParentID]
# 2                               ,[BirthDate]
# 3                                ,[GenderId]
# 4                              ,[postalcode]
# 5                            ,[Provincename]
# 6                              ,[countyname]
# 7                                 ,[isurban]
# 8                              ,[AmCrdtr_95]
# 9                               ,[Amdbtr_95]
# 10                             ,[frstPrd_95]
# 11                              ,[lstPrd_95]
# 12                              ,[SmBnft_95]
# 13                             ,[AmCrdtr_96]
# 14                              ,[Amdbtr_96]
# 15                             ,[frstPrd_96]
# 16                              ,[lstPrd_96]
# 17                              ,[SmBnft_96]
# 18                             ,[AmCrdtr_97]
# 19                              ,[Amdbtr_97]
# ...

# %% [markdown]
# 1- Which columns are not useful for now to ignore
#
#    * why?
#
# 2- List of questions based on column description we just see.
#
#     1- Number of Men and Women?
#     2- Selection of records based on Birthdate is random?
#     3- ID is random?
#     3- Province is random?
#     4- Distribution of Daramad
#     5- Is there a person with no income which has more than 1 car?

# %%
df.shape
# Out:
# (1000, 48)

# %%
df.GenderId.value_counts()
# Out:
# 1    529
# 2    471
# Name: GenderId, dtype: int64

# %% [markdown]
# ## date time sample

# %%
df.BirthDate.dtypes
# Out:
# dtype('O')

# %%
df.BirthDate.head()
# Out:
# 0    1978-03-22
# 1    1995-02-05
# 2    1970-05-13
# 3    1969-03-21
# 4    2004-06-19
# Name: BirthDate, dtype: object

# %%
df.BirthDate.value_counts(sort=False) # value_counts options
# manage date format
# Out:
# 2004-03-27    1
# 1983-12-05    1
# 1981-08-05    1
# 1996-05-01    1
# 1988-06-02    1
#              ..
# 1987-04-30    1
# 1979-06-22    2
# 1976-08-21    1
# 1966-09-01    1
# 1998-04-12    1
# Name: BirthDate, Length: 942, dtype: int64

# %%
# manage date format
df.BirthDate = pd.to_datetime(df.BirthDate, format='%Y-%m-%d')
df.BirthDate.head()
# Out:
# 0   1978-03-22
# 1   1995-02-05
# 2   1970-05-13
# 3   1969-03-21
# 4   2004-06-19
# Name: BirthDate, dtype: datetime64[ns]

# %%
df.BirthDate.dt.year.value_counts(sort=False,ascending=True).plot(kind='bar')#()
# Out:
# <AxesSubplot:>

# %%
df_year = df.BirthDate.dt.year.value_counts()

# %%
df_year.index
# Out:
# Float64Index([1985.0, 1977.0, 1983.0, 1980.0, 1984.0, 1989.0, 1990.0, 1987.0,
#               1979.0, 1992.0, 2006.0, 2016.0, 2003.0, 2012.0, 1969.0, 1981.0,
#               1994.0, 2017.0, 2011.0, 1982.0, 2007.0, 1999.0, 1978.0, 2002.0,
#               2001.0, 1971.0, 1991.0, 2008.0, 1988.0, 2019.0, 1970.0, 1986.0,
#               1998.0, 2014.0, 1993.0, 2009.0, 1968.0, 1967.0, 2004.0, 1997.0,
#               2013.0, 1959.0, 2005.0, 2000.0, 1976.0, 1973.0, 1972.0, 1975.0,
#               1974.0, 2018.0, 2015.0, 1961.0, 1996.0, 1966.0, 1995.0, 2010.0,
#               1964.0, 1955.0, 1962.0, 1960.0, 1957.0, 1952.0, 1949.0, 1963.0,
#               1958.0, 1939.0, 1945.0, 1953.0, 1956.0, 1950.0, 1965.0, 1954.0,
#               2020.0, 1946.0, 1944.0, 1938.0, 1942.0, 1948.0, 1943.0, 1947.0,
#               1937.0, 1936.0, 1951.0, 1931.0, 1925.0, 1928.0, 1926.0, 1933.0],
#              dtype='float64')

# %%
# sort_index or sort_values?
df_year.sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# https://matplotlib.org/stable/gallery/text_labels_and_annotations/date.html
import matplotlib.dates as mdates
#fig = plt.figure()
#ax = fig.add_subplot(1,1,1)  
ax1 = ax.xaxis.set_major_locator(mdates.MonthLocator(interval=5*12))
ax1 = ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))

df_year.sort_index().plot(kind='bar', ax = ax1, rot=45) #plt.plot( x, y )




#ax.xaxis.set_major_locator(mdates.MinuteLocator(interval=15))   #to get a tick every 15 minutes
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
# Out:
# <AxesSubplot:>

# %%
df_year.sort_index(inplace=True)

# %%
# make more

# %% [markdown]
# ## ?  sample

# %% [markdown]
# ## Check IDs

# %%
df.ID.head()
# Out:
# 0     385996899
# 1    2633686968
# 2     312125928
# 3      70847160
# 4     663191175
# Name: ID, dtype: int64

# %%
df['ID_length'] = len(df.ID) #?
df.ID_length.describe()#hist()
# Out:
# count    1000.0
# mean     1000.0
# std         0.0
# min      1000.0
# 25%      1000.0
# 50%      1000.0
# 75%      1000.0
# max      1000.0
# Name: ID_length, dtype: float64

# %%
df['ID_length_1'] = df.ID.astype('str').str.len()
df['ID_length_1'].describe()#hist()
# Out:
# count    1000.000000
# mean        9.978000
# std         0.477225
# min         7.000000
# 25%        10.000000
# 50%        10.000000
# 75%        10.000000
# max        11.000000
# Name: ID_length_1, dtype: float64

# %%
df['ID_length_1'].value_counts()
# Out:
# 10    795
# 9     104
# 11     95
# 8       5
# 7       1
# Name: ID_length_1, dtype: int64

# %%
df['ID_length'] = df['ID_length_1']

# %%
del df['ID_length_1']

# %%
df.ID.hist()
# Out:
# <AxesSubplot:>

# %%
df['ParentID_length'] = df.ParentID.astype('str').str.len()

# %%
df.ParentID_length.value_counts()
# Out:
# 10    840
# 9     104
# 11     48
# 8       8
# Name: ParentID_length, dtype: int64

# %%
## check relation between IDs

# %%
## check 'Card99_Rials'

# %%
df['Card99_Rials'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Let's test distribution of income to see if any similarities withknown distributions and expectation!

# %%
import numpy as np
import statsmodels.api as sm
import pylab as py
  
# np.random generates different random numbers
# whenever the code is executed
# Note: When you execute the same code 
# the graph look different than shown below.
  
# Random data points generated
data_points = np.random.normal(0, 1, 100)    
  
sm.qqplot(data_points, line ='45')
py.show()

# %%
sm.qqplot(df['Card99_Rials'])

# %%
from scipy import stats
import matplotlib.pyplot as plt

stats.probplot(df['Card99_Rials'], dist="norm", plot=plt)

#plt.show()
# Out:
# ((array([-4.90594616, -4.72894567, -4.63333147, ...,  4.63333147,
#           4.72894567,  4.90594616]),
#   array([          0,           0,           0, ..., 54747812055,
#          54747812055, 54747812055], dtype=int64)),
#  (491001147.5402305, 260079251.27838042, 0.45416866053686566))

# %%
from typing import List


def initialize(liters: float = 12.0, cutoff: int = 12) -> List[float]:
    """Return the initial array, given a starting size and cutoff for 'old'."""
    # return a list with [0.0, 0.0, 0.0, ..., liters]
    return [0.0] * cutoff + [liters]


def remove(transmission: List[float], liters: float = 1.0) -> List[float]:
    """Remove some amount of fluid from the transmission proportionally."""
    total = sum(transmission)
    return [x * (1 - liters / total) for x in transmission]


def shift(transmission: List[float], step: int = 1) -> List[float]:
    """Shift the transmission array by a number of steps to the right."""
    step = min(step, len(transmission))
    out = [0.0] * step + transmission[:-step]
    out[-1] += sum(transmission[-step:])
    return out


def refill(transmission: List[float], liters: float = 1.0) -> List[float]:
    """Refill the transmission with some amount of fluid."""
    return [x + liters if i == 0 else x for i, x in enumerate(transmission)]


def simulate(
    months: int, initial: float = 12.0, replace: float = 1.0, step: int = 1
) -> List[float]:
    """Simulate a number of months of removing/refilling transmission fluid."""
    t = initialize(initial)
    for _ in range(months):
        t = refill(shift(remove(t, replace), step), replace)
    return t

# %%
# 2. some process on data
# 3. visualize 
# 4. write result as excel, csv , txt

l = df.columns

df = df[['BirthDate', 'GenderId', 'isurban', 'daramad_Total_Rials', 'Cars_Count']]

df['Daramad_MT'] = df['daramad_Total_Rials'] / (10**7)
del df['daramad_Total_Rials']

df.Daramad_MT.plot(kind = 'bar')
df.Daramad_MT.hist(bins=100)
df.Daramad_MT[df.Daramad_MT>0].hist(bins=100)
df.Daramad_MT[df.Daramad_MT>0].plot.box()

df.Daramad_MT[(df.Daramad_MT>0)&(df.Daramad_MT<100)].hist(bins=100)

df.Daramad_MT.describe()
# Out[24]: 
# count    1.490991e+06
# mean     9.195848e-01
# std      2.265327e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      9.034895e-02
# max      4.308560e+02
# Name: Daramad_MT, dtype: float64

df.Daramad_MT[df.Daramad_MT>0].describe()
# Out[25]: 
# count    3.733760e+05
# mean     3.672150e+00
# std      3.222493e+00
# min      1.000000e-07
# 25%      1.974108e+00
# 50%      2.660014e+00
# 75%      4.675101e+00
# max      4.308560e+02
# Name: Daramad_MT, dtype: float64

df.describe()
#           GenderId   Cars_Count   Daramad_MT
# count  1000.000000  1000.000000  1000.000000
# mean      1.471000     0.252000     0.903490
# std       0.499408     0.542946     2.119113
# min       1.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000
# 50%       1.000000     0.000000     0.000000
# 75%       2.000000     0.000000     0.035788
# max       2.000000     4.000000    21.430996

df.info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype  
# ---  ------      --------------  -----  
#  0   BirthDate   991 non-null    object 
#  1   GenderId    1000 non-null   int64  
#  2   isurban     983 non-null    object 
#  3   Cars_Count  1000 non-null   int64  
#  4   Daramad_MT  1000 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 39.2+ KB

df.dtypes

# BirthDate               object
# GenderId                 int64
# isurban                 object
# daramad_Total_Rials      int64
# Cars_Count               int64
# Daramad_MT             float64
# dtype: object

df[df.Daramad_MT>0].plot.scatter(x = 'Cars_Count' , y = 'Daramad_MT')
df[df.Daramad_MT>0].plot.scatter(x = 'GenderId' , y = 'Daramad_MT')
df[df.Daramad_MT>0].plot.hist(x = 'GenderId' , y = 'Daramad_MT')
df.Daramad_MT[df.Daramad_MT>0].plot.box(by = 'GenderId')



a = df.Daramad_MT.value_counts()

b = df.Daramad_MT.value_counts(ascending= True,bins= 10)

c = df.Daramad_MT[df.Daramad_MT>0].value_counts(ascending= True,bins= 10)

####### working with whole dataset #######
col_list = ['BirthDate', 'GenderId', 'isurban', 'daramad_Total_Rials',\
            'Cars_Count']
df = pd.read_csv('Sample2Percent_Refah_4000412.xlsx.csv',usecols = col_list)  
df.BirthDate = pd.to_datetime(df.BirthDate, format='%Y-%m-%d', errors='coerce')
df['Daramad_MT'] = df['daramad_Total_Rials'] / (10**7)
del df['daramad_Total_Rials']


df.dtypes
df.BirthDate.hist(bins=200)

a = df.Daramad_MT.value_counts()

b = df.Daramad_MT.value_counts(ascending= True,bins= 10)

c = df.Daramad_MT[df.Daramad_MT>0].value_counts(ascending= True,bins= 10)
df[df.Daramad_MT>0].plot.scatter(x = 'Cars_Count' , y = 'Daramad_MT')
df[df.Daramad_MT>0].plot.scatter(x = 'GenderId' , y = 'Daramad_MT')

#https://www.python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
# sns.set(style="darkgrid")
 
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# assigning a graph to each ax
data = df[(df.Daramad_MT<100)&(df.Daramad_MT>0)]
sns.boxplot(data["Daramad_MT"], ax=ax_box)
sns.histplot(data, x="Daramad_MT",bins = 50, stat = 'density', ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')


sns.histplot(data , x="Daramad_MT", hue="GenderId")
sns.histplot(data , x="Daramad_MT", hue="GenderId", multiple="stack",kde = True,\
             logscale = True)


sns.histplot(penguins, x="flipper_length_mm", hue="species", element="step")

import seaborn as sns

# Group by time ['BirthDate']
df[['Cars_Count', 'Daramad_MT', 'isurban','GenderId']].hist(by=['isurban','GenderId'], bins = 100)#,figsize=(18, 12))

sns.scatterplot(data = df[df.Daramad_MT<100], x="Daramad_MT", y="Cars_Count", hue="isurban")

sns.relplot(
    data= df[(df.Daramad_MT<100)&(df.Cars_Count<40)], x="Cars_Count",\
    y="Daramad_MT", col="GenderId", hue="isurban",# style="day",
    kind="scatter"
)

# https://refahdb.mcls.gov.ir/fa/sample
# # Recommended Resources
# https://pbpython.com/pages/resources.html

# https://pandas.pydata.org/docs/user_guide/index.html
# https://pandas.pydata.org/docs/user_guide/10min.html
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
# plotting:
# https://regenerativetoday.com/a-complete-cheat-sheet-for-data-visualization-in-pandas/


# Cheat sheet:
# https://github.com/jupihes/SQL-versus-Pandas/blob/master/Pandas%20SQL-like%20functionality.ipynb
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\H8DED~1.MOH\AppData\Local\Temp/ipykernel_41012/1528544333.py in <module>
#      13 df.Daramad_MT.hist(bins=100)
#      14 df.Daramad_MT[df.Daramad_MT>0].hist(bins=100)
# ---> 15 df.Daramad_MT[df.Daramad_MT>0].plot.box()
#      16
#      17 df.Daramad_MT[(df.Daramad_MT>0)&(df.Daramad_MT<100)].hist(bins=100)
#
# D:\h.mohammadhosseini\Anaconda3\lib\site-packages\pandas\plotting\_core.py in box(self, by, **kwargs)
#    1247             >>> ax = df.plot.box()
#    1248         """
# -> 1249         return self(kind="box", by=by, **kwargs)
#    1250
#    1251     def hist(self, by=None, bins=10, **kwargs):
#
# D:\h.mohammadhosseini\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# ...

# %% [markdown]
# ### Resources for further learning

# %%
from IPython.core.display import display, HTML
display(HTML('<h1>Hello, world!</h1>'))
# Out:
# <h1>Hello, world!</h1>

# %%
display(HTML('https://github.com/tommyod/awesome-pandas/blob/master/README.md'))
# Out:
# <!DOCTYPE html>
# <html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#   <link rel="preconnect" href="https://github.githubassets.com" crossorigin>
#   <link rel="preconnect" href="https://avatars.githubusercontent.com">
#
#
#
# ...
